# %% [markdown]
# # People Analytics Case Study

# %% [markdown]
# ## 1. Libraries

# %%
# import libraries
import pandas as pd
import pymysql
from sqlalchemy import create_engine
import getpass

# %% [markdown]
# ## 2. Data Overview

# %%
# load data
df = pd.read_csv('../data/raw/hr_data.csv')

# %%
# View the DataFrame
df
# Out:
#                id first_name    last_name  birthdate  gender  \
# 0      00-0037846      Kimmy   Walczynski   6/4/1991    Male
# 1      00-0041533   Ignatius    Springett  6/29/1984    Male
# 2      00-0045747     Corbie  Bittlestone  7/29/1989    Male
# 3      00-0055274       Baxy       Matton  9/14/1982  Female
# 4      00-0076100    Terrell         Suff  4/11/1994  Female
# ...           ...        ...          ...        ...     ...
# 37403         NaN        NaN          NaN        NaN     NaN
# 37404         NaN        NaN          NaN        NaN     NaN
# 37405         NaN        NaN          NaN        NaN     NaN
# 37406         NaN        NaN          NaN        NaN     NaN
# 37407         NaN        NaN          NaN        NaN     NaN
#
#                             race            department  \
# 0             Hispanic or Latino           Engineering
# 1                          White  Business Development
# 2      Black or African American                 Sales
# 3                          White              Services
# 4              Two or More Races    Product Management
# ...                          ...                   ...
# 37403                        NaN                   NaN
# 37404                        NaN                   NaN
# 37405                        NaN                   NaN
# 37406                        NaN                   NaN
# 37407                        NaN                   NaN
#
#                          jobtitle      location   hire_date  \
# 0            Programmer Analyst I  Headquarters   1/20/2002
# 1                Business Analyst  Headquarters    4/8/2019
# 2      Solutions Engineer Manager  Headquarters  10/12/2010
# 3                    Service Tech  Headquarters   4/10/2005
# 4                Business Analyst        Remote   9/29/2010
# ...                           ...           ...         ...
# 37403                         NaN           NaN         NaN
# 37404                         NaN           NaN         NaN
# 37405                         NaN           NaN         NaN
# 37406                         NaN           NaN         NaN
# 37407                         NaN           NaN         NaN
#
#                       termdate location_city location_state
# 0                          NaN     Cleveland           Ohio
# 1                          NaN     Cleveland           Ohio
# 2                          NaN     Cleveland           Ohio
# 3                          NaN     Cleveland           Ohio
# 4      2029-10-29 06:09:38 UTC         Flint       Michigan
# ...                        ...           ...            ...
# 37403                      NaN           NaN            NaN
# 37404                      NaN           NaN            NaN
# 37405                      NaN           NaN            NaN
# 37406                      NaN           NaN            NaN
# 37407                      NaN           NaN            NaN
#
# [37408 rows x 13 columns]

# %%
# General information about the DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37408 entries, 0 to 37407
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              22214 non-null  object
#  1   first_name      22214 non-null  object
#  2   last_name       22214 non-null  object
#  3   birthdate       22214 non-null  object
#  4   gender          22214 non-null  object
#  5   race            22214 non-null  object
#  6   department      22214 non-null  object
#  7   jobtitle        22267 non-null  object
#  8   location        22214 non-null  object
#  9   hire_date       22214 non-null  object
#  10  termdate        3929 non-null   object
#  11  location_city   22214 non-null  object
#  12  location_state  22214 non-null  object
# dtypes: object(13)
# memory usage: 3.7+ MB

# %% [markdown]
# ## 3. Data Cleaning

# %%
# Rename columns in the DataFrame
df = df.rename(columns={
    'birthdate': 'birth_date',
    'jobtitle': 'job_title',
    'termdate': 'term_date',
    'id': 'emp_id'
})

# %%
# Remove rows where all values are NaN (empty)
df = df.dropna(how='all')

# %%
df
# Out:
#            emp_id first_name    last_name birth_date  gender  \
# 0      00-0037846      Kimmy   Walczynski   6/4/1991    Male
# 1      00-0041533   Ignatius    Springett  6/29/1984    Male
# 2      00-0045747     Corbie  Bittlestone  7/29/1989    Male
# 3      00-0055274       Baxy       Matton  9/14/1982  Female
# 4      00-0076100    Terrell         Suff  4/11/1994  Female
# ...           ...        ...          ...        ...     ...
# 22433         NaN        NaN          NaN        NaN     NaN
# 22434         NaN        NaN          NaN        NaN     NaN
# 22435         NaN        NaN          NaN        NaN     NaN
# 22436         NaN        NaN          NaN        NaN     NaN
# 22437         NaN        NaN          NaN        NaN     NaN
#
#                             race            department  \
# 0             Hispanic or Latino           Engineering
# 1                          White  Business Development
# 2      Black or African American                 Sales
# 3                          White              Services
# 4              Two or More Races    Product Management
# ...                          ...                   ...
# 22433                        NaN                   NaN
# 22434                        NaN                   NaN
# 22435                        NaN                   NaN
# 22436                        NaN                   NaN
# 22437                        NaN                   NaN
#
#                         job_title      location   hire_date  \
# 0            Programmer Analyst I  Headquarters   1/20/2002
# 1                Business Analyst  Headquarters    4/8/2019
# 2      Solutions Engineer Manager  Headquarters  10/12/2010
# 3                    Service Tech  Headquarters   4/10/2005
# 4                Business Analyst        Remote   9/29/2010
# ...                           ...           ...         ...
# 22433           Support Staff III           NaN         NaN
# 22434           Support Staff III           NaN         NaN
# 22435           Support Staff III           NaN         NaN
# 22436           Support Staff III           NaN         NaN
# 22437           Support Staff III           NaN         NaN
#
#                      term_date location_city location_state
# 0                          NaN     Cleveland           Ohio
# 1                          NaN     Cleveland           Ohio
# 2                          NaN     Cleveland           Ohio
# 3                          NaN     Cleveland           Ohio
# 4      2029-10-29 06:09:38 UTC         Flint       Michigan
# ...                        ...           ...            ...
# 22433                      NaN           NaN            NaN
# 22434                      NaN           NaN            NaN
# 22435                      NaN           NaN            NaN
# 22436                      NaN           NaN            NaN
# 22437                      NaN           NaN            NaN
#
# [22267 rows x 13 columns]

# %%
# Check for duplicated rows
df.duplicated().sum()
# Out:
# 50

# %%
# Show duplicated rows
df[df.duplicated()]
# Out:
#       emp_id first_name last_name birth_date gender race department  \
# 22322    NaN        NaN       NaN        NaN    NaN  NaN        NaN
# 22323    NaN        NaN       NaN        NaN    NaN  NaN        NaN
# 22324    NaN        NaN       NaN        NaN    NaN  NaN        NaN
# 22325    NaN        NaN       NaN        NaN    NaN  NaN        NaN
# 22326    NaN        NaN       NaN        NaN    NaN  NaN        NaN
# 22327    NaN        NaN       NaN        NaN    NaN  NaN        NaN
# 22328    NaN        NaN       NaN        NaN    NaN  NaN        NaN
# 22329    NaN        NaN       NaN        NaN    NaN  NaN        NaN
# 22330    NaN        NaN       NaN        NaN    NaN  NaN        NaN
# 22331    NaN        NaN       NaN        NaN    NaN  NaN        NaN
# 22332    NaN        NaN       NaN        NaN    NaN  NaN        NaN
# 22333    NaN        NaN       NaN        NaN    NaN  NaN        NaN
# 22334    NaN        NaN       NaN        NaN    NaN  NaN        NaN
# 22335    NaN        NaN       NaN        NaN    NaN  NaN        NaN
# 22336    NaN        NaN       NaN        NaN    NaN  NaN        NaN
# 22337    NaN        NaN       NaN        NaN    NaN  NaN        NaN
# 22338    NaN        NaN       NaN        NaN    NaN  NaN        NaN
# 22339    NaN        NaN       NaN        NaN    NaN  NaN        NaN
# 22340    NaN        NaN       NaN        NaN    NaN  NaN        NaN
# 22405    NaN        NaN       NaN        NaN    NaN  NaN        NaN
# 22406    NaN        NaN       NaN        NaN    NaN  NaN        NaN
# 22407    NaN        NaN       NaN        NaN    NaN  NaN        NaN
# 22408    NaN        NaN       NaN        NaN    NaN  NaN        NaN
# 22409    NaN        NaN       NaN        NaN    NaN  NaN        NaN
# 22410    NaN        NaN       NaN        NaN    NaN  NaN        NaN
# 22411    NaN        NaN       NaN        NaN    NaN  NaN        NaN
# 22412    NaN        NaN       NaN        NaN    NaN  NaN        NaN
# 22413    NaN        NaN       NaN        NaN    NaN  NaN        NaN
# 22414    NaN        NaN       NaN        NaN    NaN  NaN        NaN
# 22415    NaN        NaN       NaN        NaN    NaN  NaN        NaN
# 22416    NaN        NaN       NaN        NaN    NaN  NaN        NaN
# 22419    NaN        NaN       NaN        NaN    NaN  NaN        NaN
# 22420    NaN        NaN       NaN        NaN    NaN  NaN        NaN
# 22421    NaN        NaN       NaN        NaN    NaN  NaN        NaN
# 22422    NaN        NaN       NaN        NaN    NaN  NaN        NaN
# 22423    NaN        NaN       NaN        NaN    NaN  NaN        NaN
# 22424    NaN        NaN       NaN        NaN    NaN  NaN        NaN
# 22425    NaN        NaN       NaN        NaN    NaN  NaN        NaN
# 22426    NaN        NaN       NaN        NaN    NaN  NaN        NaN
# 22427    NaN        NaN       NaN        NaN    NaN  NaN        NaN
# 22428    NaN        NaN       NaN        NaN    NaN  NaN        NaN
# 22429    NaN        NaN       NaN        NaN    NaN  NaN        NaN
# 22430    NaN        NaN       NaN        NaN    NaN  NaN        NaN
# 22431    NaN        NaN       NaN        NaN    NaN  NaN        NaN
# 22432    NaN        NaN       NaN        NaN    NaN  NaN        NaN
# 22433    NaN        NaN       NaN        NaN    NaN  NaN        NaN
# 22434    NaN        NaN       NaN        NaN    NaN  NaN        NaN
# 22435    NaN        NaN       NaN        NaN    NaN  NaN        NaN
# 22436    NaN        NaN       NaN        NaN    NaN  NaN        NaN
# 22437    NaN        NaN       NaN        NaN    NaN  NaN        NaN
#
#                job_title location hire_date term_date location_city  \
# 22322   Support Staff II      NaN       NaN       NaN           NaN
# 22323   Support Staff II      NaN       NaN       NaN           NaN
# 22324   Support Staff II      NaN       NaN       NaN           NaN
# 22325   Support Staff II      NaN       NaN       NaN           NaN
# 22412            NaN
# 22413            NaN
# 22414            NaN
# 22415            NaN
# 22416            NaN
# 22419            NaN
# 22420            NaN
# 22421            NaN
# 22422            NaN
# 22423            NaN
# 22424            NaN
# 22425            NaN
# 22426            NaN
# 22427            NaN
# 22428            NaN
# 22429            NaN
# 22430            NaN
# 22431            NaN
# 22432            NaN
# 22433            NaN
# 22434            NaN
# 22435            NaN
# 22436            NaN
# 22437            NaN

# %%
# Remove rows where all columns except 'jobtitle' are NaN
df = df.dropna(how='all', subset=df.columns.difference(['job_title']))

# %%
# Count the occurrences of each value in the 'id' column
duplicate_counts = df['emp_id'].value_counts()

# Filter the counts to show only duplicates
duplicates = duplicate_counts[duplicate_counts > 1]

# Show the duplicated ids and their counts
print(duplicates)
# Out:
# Series([], Name: count, dtype: int64)

# %%
# Dropping the 'location_city' column as it's not relevant for the analysis
df.drop(columns=['location_city'], inplace=True)
# Out:
# /var/folders/lb/xlcp_nw57bz0k682c287nrk00000gn/T/ipykernel_95405/1230876464.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['location_city'], inplace=True)

# %%
# Count unique values in 'location_state'
df['location_state'].value_counts()
# Out:
# location_state
# Ohio            18025
# Pennsylvania     1115
# Illinois          868
# Indiana           700
# Michigan          673
# Kentucky          451
# Wisconsin         382
# Name: count, dtype: int64

# %%
# Mapping states to California and neighboring states for storytelling purposes.
# The original dataset is fictitious, allowing for creative flexibility in the analysis.

state_mapping = {
    'Ohio': 'California',
    'Pennsylvania': 'Oregon',
    'Illinois': 'Nevada',
    'Indiana': 'Arizona',
    'Michigan': 'Utah',
    'Kentucky': 'New Mexico',
    'Wisconsin': 'Idaho'
}

# Apply the mapping to the 'location_state' column
df['location_state'] = df['location_state'].replace(state_mapping)
# Out:
# /var/folders/lb/xlcp_nw57bz0k682c287nrk00000gn/T/ipykernel_95405/2314722448.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['location_state'] = df['location_state'].replace(state_mapping)

# %%
# Count unique values in 'location_state'
df['location_state'].value_counts()
# Out:
# location_state
# California    18025
# Oregon         1115
# Nevada          868
# Arizona         700
# Utah            673
# New Mexico      451
# Idaho           382
# Name: count, dtype: int64

# %%
df.dtypes
# Out:
# emp_id            object
# first_name        object
# last_name         object
# birth_date        object
# gender            object
# race              object
# department        object
# job_title         object
# location          object
# hire_date         object
# term_date         object
# location_state    object
# dtype: object

# %%
# Count the number of valid (non-null) entries in 'birth_date', 'hire_date', and 'term_date'
valid_counts = df[['birth_date', 'hire_date', 'term_date']].count()

# Print the counts of valid entries for each column
print(valid_counts)
# Out:
# birth_date    22214
# hire_date     22214
# term_date      3929
# dtype: int64

# %%
# Convert 'birth_date' and 'hire_date' to datetime format
df['birth_date'] = pd.to_datetime(df['birth_date'], errors='coerce')
df['hire_date'] = pd.to_datetime(df['hire_date'], errors='coerce')
# Out:
# /var/folders/lb/xlcp_nw57bz0k682c287nrk00000gn/T/ipykernel_95405/1115299221.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['birth_date'] = pd.to_datetime(df['birth_date'], errors='coerce')
# /var/folders/lb/xlcp_nw57bz0k682c287nrk00000gn/T/ipykernel_95405/1115299221.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['hire_date'] = pd.to_datetime(df['hire_date'], errors='coerce')

# %%
# Convert the 'term_date' column from string to datetime format and extract only the date
df['term_date'] = pd.to_datetime(df['term_date']).dt.date

# Convert the 'term_date' column back to datetime format with default time (00:00:00)
df['term_date'] = pd.to_datetime(df['term_date'])
# Out:
# /var/folders/lb/xlcp_nw57bz0k682c287nrk00000gn/T/ipykernel_95405/1376337505.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['term_date'] = pd.to_datetime(df['term_date']).dt.date
# /var/folders/lb/xlcp_nw57bz0k682c287nrk00000gn/T/ipykernel_95405/1376337505.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['term_date'] = pd.to_datetime(df['term_date'])

# %%
# Count the number of valid (non-null) entries in 'birth_date', 'hire_date', and 'term_date'
valid_counts = df[['birth_date', 'hire_date', 'term_date']].count()

# Print the counts of valid entries for each column
print(valid_counts)
# Out:
# birth_date    22214
# hire_date     22214
# term_date      3929
# dtype: int64

# %%
# General information about the DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22214 entries, 0 to 22213
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   emp_id          22214 non-null  object
#  1   first_name      22214 non-null  object
#  2   last_name       22214 non-null  object
#  3   birth_date      22214 non-null  datetime64[ns]
#  4   gender          22214 non-null  object
#  5   race            22214 non-null  object
#  6   department      22214 non-null  object
#  7   job_title       22214 non-null  object
#  8   location        22214 non-null  object
#  9   hire_date       22214 non-null  datetime64[ns]
#  10  term_date       3929 non-null   datetime64[ns]
#  11  location_state  22214 non-null  object
# dtypes: datetime64[ns](3), object(9)
# memory usage: 2.2+ MB

# %%
# Create a dictionary to store the min and max values for clarity
date_ranges = {
    'Birth Date': {'Min': df['birth_date'].min(), 'Max': df['birth_date'].max()},
    'Hire Date': {'Min': df['hire_date'].min(), 'Max': df['hire_date'].max()},
    'Term Date': {'Min': df['term_date'].min(), 'Max': df['term_date'].max()}
}

# Convert to a DataFrame for a cleaner output
date_ranges_df = pd.DataFrame(date_ranges)

# Show the date ranges
date_ranges_df
# Out:
#     Birth Date  Hire Date  Term Date
# Min 1965-10-16 2000-10-17 2001-04-15
# Max 2002-09-13 2020-12-13 2041-10-29

# %%
# Get the current timestamp
current_timestamp = pd.Timestamp('now')

# Filter rows where 'term_date' is greater than current date
term_date_invalid = df[df['term_date'] > current_timestamp]

# Show the filtered rows
term_date_invalid
# Out:
#            emp_id first_name     last_name birth_date  gender  \
# 4      00-0076100    Terrell          Suff 1994-04-11  Female
# 27     00-1268049        Fay      Monnelly 1966-07-09    Male
# 40     00-1792130       Nobe        Leathe 1993-07-23    Male
# 57     00-2623755     Chrysa      Brownell 1983-04-25    Male
# 139    00-6479395       Aura      Steagall 1978-07-19    Male
# ...           ...        ...           ...        ...     ...
# 22038  99-1005402    Cornela     Livermore 1969-10-14  Female
# 22048  99-1707394    Patrick       Musicka 1976-04-23  Female
# 22083  99-3706255      Nappy      Burchess 1999-10-22    Male
# 22095  99-4396036      Flory  Hardy-Piggin 1989-03-28    Male
# 22127  99-5871990     Brenda          Wank 1983-08-13    Male
#
#                                             race          department  \
# 4                              Two or More Races  Product Management
# 27     Native Hawaiian or Other Pacific Islander         Engineering
# 40                     Black or African American         Engineering
# 57                                         White         Engineering
# 139                                        White          Accounting
# ...                                          ...                 ...
# 22038                          Two or More Races         Engineering
# 22048                          Two or More Races     Human Resources
# 22083  Native Hawaiian or Other Pacific Islander          Accounting
# 22095                  Black or African American          Accounting
# 22127                                      Asian            Training
#
#                           job_title      location  hire_date  term_date  \
# 4                  Business Analyst        Remote 2010-09-29 2029-10-29
# 27              Software Engineer I  Headquarters 2010-02-24 2030-03-21
# 40                    Developer III  Headquarters 2011-01-23 2024-12-07
# 57           Administrative Officer  Headquarters 2018-02-22 2027-02-01
# 139              Staff Accountant I  Headquarters 2013-03-28 2030-02-23
# ...                             ...           ...        ...        ...
# 22038      Software Test Engineer I        Remote 2013-06-02 2030-01-30
# 22048              Senior Recruiter  Headquarters 2016-11-25 2026-08-01
# 22083  Budget/Accounting Analyst II  Headquarters 2017-12-31 2035-08-20
# 22095        Administrative Officer        Remote 2019-03-26 2027-03-03
# 22127    Administrative Assistant I  Headquarters 2012-07-18 2028-03-02
#
#       location_state
# 4               Utah
# 27        California
# 40        California
# 57        California
# 139       California
# ...              ...
# 22038         Nevada
# 22048     California
# 22083     California
# 22095        Arizona
# 22127     California
#
# [1327 rows x 12 columns]

# %%
# Define the cutoff date as 31st December 2020
cutoff_date = pd.Timestamp('2020-12-31')

# Drop rows where 'term_date' is greater than the cutoff date
df = df.drop(df[df['term_date'] > cutoff_date].index)

# Check the number of rows after the removal
remaining_rows = len(df)
remaining_rows
# Out:
# 20183

# %%
# Define a timedelta of 3 years using pd.DateOffset
# We are adding 3 years to the existing dates for storytelling purposes, so that events that happened in the past
# (such as 2020) will now appear as if they occurred in 2023. This gives the dataset a more current context.
three_years = pd.DateOffset(years=3)

# Add 3 years to each of the date columns ('birth_date', 'hire_date', 'term_date')
# This shifts all dates forward by 3 years, making the dataset feel more relevant to the current time period.
df['birth_date'] = df['birth_date'] + three_years
df['hire_date'] = df['hire_date'] + three_years
df['term_date'] = df['term_date'] + three_years

# %%
#BORRAAAAAAAAAAAAAAARRRRRRRRRRRRRRR

df.sort_values(by='hire_date', ascending=False).head(50)
# Out:
#            emp_id first_name      last_name birth_date  age          gender  \
# 9802   44-1463409       Jehu         Caroll 1987-06-11   37          Female
# 13278  59-7815002    Kennith   Marjoribanks 1989-04-16   35            Male
# 18867  84-5815265    Nanette         Kirgan 2003-04-18   21            Male
# 2467   11-2348367      Reese       Nattrass 1992-07-19   32            Male
# 6956   31-4715846      Tucky         Crosby 1981-10-14   43            Male
# 17024  76-3309194      Jakie           Jent 1990-09-08   34          Female
# 2543   11-5197257    Laurens            Law 1977-04-07   47            Male
# 19801  89-0545531      Quent          Taffs 1983-08-09   41            Male
# 13440  60-5239423    Angelia         Vlasov 1999-05-31   25          Female
# 18783  84-2343788    Aveline         Coffin 1988-10-16   36  Non-Conforming
# 12388  55-6062005       Theo           Boar 1999-08-30   25          Female
# 15410  69-1258909     Albert        Bonnett 1990-10-20   34            Male
# 4906   22-1251067    Padraig       Rodolico 1973-06-10   51            Male
# 16011  71-7118852   Sunshine      Alderwick 1976-11-20   48            Male
# 14555      Software Test Engineer IV  Headquarters 2023-11-30       NaT
# 15255          Content Developer III  Headquarters 2023-11-29       NaT
# 1045   Data Visualization Specialist  Headquarters 2023-11-29       NaT
# 7925                  Programmer III  Headquarters 2023-11-28       NaT
# 13368        Accounting Assistant II  Headquarters 2023-11-28       NaT
# 10199                Cost Accountant  Headquarters 2023-11-28       NaT
# 9459                 Project Manager  Headquarters 2023-11-28       NaT
# 8451                     Developer I  Headquarters 2023-11-27       NaT
# 20401     Quality Control Specialist        Remote 2023-11-27       NaT
# 19169       Senior Financial Analyst  Headquarters 2023-11-26       NaT
# 12185     Database Administrator III  Headquarters 2023-11-26       NaT
# 11623      Software Test Engineer II  Headquarters 2023-11-25       NaT
# 11982          Research Assistant II        Remote 2023-11-24       NaT
# 19401                 Junior Trainer  Headquarters 2023-11-24       NaT
# 18350                  Senior Editor  Headquarters 2023-11-24       NaT
# 15606       Software Test Engineer I  Headquarters 2023-11-23       NaT
# 12938                 Senior Trainer  Headquarters 2023-11-21       NaT
# 12555          Chief Design Engineer  Headquarters 2023-11-21       NaT
# 11826        Human Resources Analyst  Headquarters 2023-11-21       NaT
#
#       location_state
# 9802      California
# 13278     California
# 18867     California
# 2467      California
# 6956      California
# 17024     California
# 2543      California
# 19801     California
# 13440     California
# 18783     California
# 12388     California
# 15410     California
# 4906      California
# 16011     New Mexico
# 16511     California
# 14568     California
# 13452         Nevada
# 10088           Utah
# 13947     California
# 17638     California
# 19624     California
# 10303     California
# 2409           Idaho
# 16543     California
# 9314      California
# 8408      California
# 13633     California
# 21732     California
# 12208     California
# 13938     California
# 5639          Oregon
# 14555     California
# 15255     California
# 1045      California
# 7925      California
# 13368     California
# 10199     California
# 9459      California
# 8451      California
# 20401     California
# 19169     California
# 12185     California
# 11623     California
# 11982     New Mexico
# 19401     California
# 18350     California
# 15606     California
# 12938     California
# 12555     California
# 11826     California

# %%
# Get distinct values in the 'gender' column
distinct_gender = df['gender'].unique()

# Show the unique values
distinct_gender
# Out:
# array(['Male', 'Female', 'Non-Conforming'], dtype=object)

# %%
# Get distinct values in the 'race' column
distinct_race = df['race'].unique()

# Show the unique values
distinct_race
# Out:
# array(['Hispanic or Latino', 'White', 'Black or African American',
#        'Asian', 'Two or More Races', 'American Indian or Alaska Native',
#        'Native Hawaiian or Other Pacific Islander'], dtype=object)

# %%
# Check for empty values in 'race' and 'gender' columns
empty_values = df[df['race'].isnull() | df['gender'].isnull()]

# Show the rows with empty values
empty_values
# Out:
# Empty DataFrame
# Columns: [emp_id, first_name, last_name, birth_date, gender, race, department, job_title, location, hire_date, term_date, location_state]
# Index: []

# %%
# Check for null values in all columns
null_counts = df.isnull().sum()

# Show columns with null values
null_counts[null_counts > 0]
# Out:
# term_date    18285
# dtype: int64

# %%
# Calculate age based on 'birth_date'
current_year = pd.Timestamp('now').year
age = current_year - df['birth_date'].dt.year

# Insert the 'age' column at index 4 (fifth position)
df.insert(4, 'age', age)

# Display the DataFrame with the new 'age' column
df
# Out:
#            emp_id first_name    last_name birth_date  age  gender  \
# 0      00-0037846      Kimmy   Walczynski 1994-06-04   30    Male
# 1      00-0041533   Ignatius    Springett 1987-06-29   37    Male
# 2      00-0045747     Corbie  Bittlestone 1992-07-29   32    Male
# 3      00-0055274       Baxy       Matton 1985-09-14   39  Female
# 5      00-0116166      Kacie      Offiler 1974-01-18   50    Male
# ...           ...        ...          ...        ...  ...     ...
# 22209  99-9797418    Dorella       Garvan 2001-07-08   23  Female
# 22210  99-9869877      Dasie      Thorsby 2004-04-19   20  Female
# 22211  99-9919822      Nerty      Wilding 1973-02-09   51  Female
# 22212  99-9960380    Mabelle        Dawks 1988-09-02   36    Male
# 22213  99-9963543    Carroll    Chattaway 2002-07-10   22  Female
#
#                             race                department  \
# 0             Hispanic or Latino               Engineering
# 1                          White      Business Development
# 2      Black or African American                     Sales
# 3                          White                  Services
# 5                          Asian               Engineering
# ...                          ...                       ...
# 22209         Hispanic or Latino  Research and Development
# 22210          Two or More Races                  Services
# 22211          Two or More Races                  Training
# 22212          Two or More Races                Accounting
# 22213                      White               Engineering
#
#                         job_title      location  hire_date  term_date  \
# 0            Programmer Analyst I  Headquarters 2005-01-20        NaT
# 1                Business Analyst  Headquarters 2022-04-08        NaT
# 2      Solutions Engineer Manager  Headquarters 2013-10-12        NaT
# 3                    Service Tech  Headquarters 2008-04-10        NaT
# 5                   Developer III  Headquarters 2021-09-01        NaT
# ...                           ...           ...        ...        ...
# 22209        Research Assistant I  Headquarters 2015-02-08        NaT
# 22210             Service Manager  Headquarters 2020-10-06        NaT
# 22211              Junior Trainer  Headquarters 2004-02-08        NaT
# 22212          Staff Accountant I  Headquarters 2008-04-03 2015-12-10
# 22213       Software Engineer III        Remote 2021-03-27        NaT
#
#       location_state
# 0         California
# 1         California
# 2         California
# 3         California
# 5         California
# ...              ...
# 22209     California
# 22210     California
# 22211     California
# 22212     California
# 22213        Arizona
#
# [20183 rows x 13 columns]

# %%
# Calculate min, avg, and max for the 'age' column
min_age = df['age'].min()
avg_age = df['age'].mean()
max_age = df['age'].max()

# Display the results
age_statistics = {
    'min_age': min_age,
    'avg_age': avg_age,
    'max_age': max_age
}

# Count the number of rows where age is less than 18
count_under_18 = df[df['age'] < 18].shape[0]

# Display the count
age_statistics, count_under_18
# Out:
# ({'min_age': 19, 'avg_age': 37.20091165832631, 'max_age': 56}, 0)

# %%
df.sort_values(by='term_date', ascending=True)
# Out:
#            emp_id first_name    last_name birth_date  age  gender  \
# 14374  64-6403747     Briggs      Eastway 1971-03-13   53  Female
# 19423  87-3003781     Menard         Bril 1992-09-25   32  Female
# 8835   39-8448824       Keir     Dechelle 2005-07-22   19    Male
# 6854   31-0270355       Joey        Agney 1980-03-08   44  Female
# 4049   18-3127889     Faydra  Matushevich 1999-12-29   25    Male
# ...           ...        ...          ...        ...  ...     ...
# 22208  99-9610988     Hillie      Renbold 1968-10-30   56  Female
# 22209  99-9797418    Dorella       Garvan 2001-07-08   23  Female
# 22210  99-9869877      Dasie      Thorsby 2004-04-19   20  Female
# 22211  99-9919822      Nerty      Wilding 1973-02-09   51  Female
# 22213  99-9963543    Carroll    Chattaway 2002-07-10   22  Female
#
#                                    race                department  \
# 14374  American Indian or Alaska Native      Business Development
# 19423  American Indian or Alaska Native                  Services
# 8835                              White                     Sales
# 6854          Black or African American                   Support
# 4049                  Two or More Races           Human Resources
# ...                                 ...                       ...
# 22208                 Two or More Races               Engineering
# 22209                Hispanic or Latino  Research and Development
# 22210                 Two or More Races                  Services
# 22211                 Two or More Races                  Training
# 22213                             White               Engineering
#
#                      job_title      location  hire_date  term_date  \
# 14374    Research Assistant II  Headquarters 2003-12-03 2004-04-15
# 19423          Service Manager  Headquarters 2004-08-28 2004-10-06
# 8835     Relationshiop Manager  Headquarters 2004-05-31 2004-10-24
# 6854             Support Staff  Headquarters 2004-09-22 2004-11-11
# 4049   Human Resources Analyst  Headquarters 2004-04-29 2004-11-30
# ...                        ...           ...        ...        ...
# 22208         Web Developer II  Headquarters 2004-12-03        NaT
# 22209     Research Assistant I  Headquarters 2015-02-08        NaT
# 22210          Service Manager  Headquarters 2020-10-06        NaT
# 22211           Junior Trainer  Headquarters 2004-02-08        NaT
# 22213    Software Engineer III        Remote 2021-03-27        NaT
#
#       location_state
# 14374     California
# 19423     California
# 8835      California
# 6854      California
# 4049      California
# ...              ...
# 22208     California
# 22209     California
# 22210     California
# 22211     California
# 22213        Arizona
#
# [20183 rows x 13 columns]

# %%
# Filter and count rows where the year in 'hire_date' is 2023
hire_date_2023 = df[df['hire_date'].dt.year == 2023].shape[0]

# Filter and count rows where the year in 'term_date' is 2023
term_date_2023 = df[df['term_date'].dt.year == 2023].shape[0]

# Filter and count rows where the year in 'hire_date' is 2003
hire_date_2003 = df[df['hire_date'].dt.year == 2003].shape[0]

# Filter and count rows where the year in 'term_date' is 2003
term_date_2003 = df[df['term_date'].dt.year == 2003].shape[0]

# Print the results separately
print(f"Number of rows where hire_date is in 2023: {hire_date_2023}")
print(f"Number of rows where term_date is in 2023: {term_date_2023}")
print(f"Number of rows where hire_date is in 2003: {hire_date_2003}")
print(f"Number of rows where term_date is in 2003: {term_date_2003}")
# Out:
# Number of rows where hire_date is in 2023: 842
# Number of rows where term_date is in 2023: 166
# Number of rows where hire_date is in 2003: 219
# Number of rows where term_date is in 2003: 0

# %%
df.dtypes
# Out:
# emp_id                    object
# first_name                object
# last_name                 object
# birth_date        datetime64[ns]
# age                        int32
# gender                    object
# race                      object
# department                object
# job_title                 object
# location                  object
# hire_date         datetime64[ns]
# term_date         datetime64[ns]
# location_state            object
# dtype: object

# %% [markdown]
# ## 4. Exporting the DataFrame to MySQL Workbench

# %%
# Connection parameters
bd = "hr_data"
password = "password"
connection_string = 'mysql+pymysql://root:' + password + '@localhost/' + bd

# Create the connection engine
engine = create_engine(connection_string)

# Send the DataFrame named 'df' to MySQL
table_name = 'employees'
df.to_sql(table_name, con=engine, if_exists='replace', index=False)
# Out:
# 20183
